# %% [markdown]
# <a href="https://colab.research.google.com/github/Peteroliobi32/MyFirstPythoncode/blob/main/MyFirstPythoncode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print ("Hello")
# Out:
# Hello

# %%
print ("Peter is up and coming")
# Out:
# Peter is up and coming
