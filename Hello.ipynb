# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-O-O-V/MyFirstPythoncode/blob/main/Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Programming World")
# Out:
# Hello, Programming World

# %%
print("From Peter to Programming world")
# Out:
# From Peter to Programming world
