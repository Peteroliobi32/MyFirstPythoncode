# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-O-O-V/MyFirstPythoncode/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assigning a Variable
My_name = "Peter Okwuchukwu Oliobi"
print (My_name)
# Out:
# Peter Okwuchukwu Oliobi
